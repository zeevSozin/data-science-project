# %%
import pandas as pd

# %%
MainDf=pd.read_csv('./DataFrames/MainDataFrame_raw.csv')
CleanDF=pd.read_csv('./DataFrames/MainDataFrameAfterCleaning.csv')

# %% [markdown]
# data before cleaning

# %%
MainDf.shape
# Out:
# (1344, 40)

# %%
MainDf.head()
# Out:
#    Unnamed: 0     Country  Year  \
# 0           0     Albania  2000
# 1           1     Armenia  2000
# 2           2   Australia  2000
# 3           3     Austria  2000
# 4           4  Azerbaijan  2000
#
#   Total inland transport infrastructure investment  \
# 0                                      110 421 157
# 1                                               ..
# 2                                    4 111 727 074
# 3                                    1 674 000 000
# 4                                       35 096 212
#
#   Rail infrastructure maintenance Road casualties (injured + killed)  \
# 0                       3 838 572                                620
# 1                              ..                              1 377
# 2                             NaN                             28 591
# 3                     508 000 000                             55 905
# 4                              ..                              2 199
#
# ...

# %%
MainDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 40 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Unnamed: 0                                                                                            1344 non-null   int64
#  1   Country                                                                                               1344 non-null   object
#  2   Year                                                                                                  1344 non-null   int64
#  3   Total inland transport infrastructure investment                                                      1029 non-null   object
# ...

# %% [markdown]
# clean data after cleaning

# %%
CleanDF.shape
# Out:
# (204, 35)

# %%
CleanDF.head()
# Out:
#    Unnamed: 0         Country  Year  \
# 0           0         Austria  2010
# 1           1  Czech Republic  2010
# 2           2         Finland  2010
# 3           3          France  2010
# 4           4         Germany  2010
#
#    Total inland transport infrastructure investment  \
# 0                                      2.337000e+09
# 1                                      2.340525e+09
# 2                                      1.280000e+09
# 3                                      1.985350e+10
# 4                                      1.715700e+10
#
#    Rail infrastructure maintenance  Total inland passenger transport  \
# 0                     5.590000e+08                               NaN
# 1                     6.698058e+08                           80977.0
# 2                     6.670000e+08                           76244.0
# 3                     2.431000e+09                          866108.0
# 4                              NaN                         1046778.0
#
# ...

# %%
CleanDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 35 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Unnamed: 0                                                                                            204 non-null    int64
#  1   Country                                                                                               204 non-null    object
#  2   Year                                                                                                  204 non-null    int64
#  3   Total inland transport infrastructure investment                                                      183 non-null    float64
# ...
